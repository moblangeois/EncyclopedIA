# %%
import pandas as pd

# ouvrir le fichier data\EDdA_dataframe_withContent.tsv
df = pd.read_csv('data/EDdA_dataframe_withContent.tsv', sep='\t')
df
# Out:
#        volume  numero                                head           normClass  \
# 0           1       1                          Title Page        unclassified
# 1           1       2   A MONSEIGNEUR LE COMTE D'ARGENSON        unclassified
# 2           1       3  DISCOURS PRÉLIMINAIRE DES EDITEURS        unclassified
# 3           1       5                            A, a & a           Grammaire
# 4           1       6                                   A        unclassified
# ...       ...     ...                                 ...                 ...
# 74185      17    3204                           TRANSFUGE       Art militaire
# 74186      17    3205                               VÉNUS          Astronomie
# 74187      17    3206                       VERS falisque       Poésie latine
# 74188      17    3207           VIBRATION, ou OSCILLATION          Horlogerie
# 74189      17    3208               VINGTIEME, imposition  Economie politique
#
# ...

# %%
# Montrer les lignes où head == abduction sans casse
df[df['head'].str.lower() == 'abduction']
# Out:
#      volume  numero       head     normClass     classEDdA author id_enccre  \
# 156       1     158  ABDUCTION  unclassified  unclassified  Tarin   v1-98-0
# 157       1     159  Abduction       Logique    en Logique   Yvon   v1-98-1
#
#     domaine_enccre ensemble_domaine_enccre  \
# 156       anatomie                Anatomie
# 157        logique             Philosophie
#
#                                                content  \
# 156  ABDUCTION, s. f. nom dont se servent les Anato...
# 157  Abduction s. f. en Logique est une façon d'arg...
#
#                                    contentWithoutClass  \
# 156  abduction s. f. nom servent anatomiste exprime...
# 157  abduction s. f.   façon argumenter \n grec nom...
#
#                                         firstParagraph  nb_words
# 156  abduction s. f. nom servent anatomiste exprime...        60
# 157  abduction s. f.   façon argumenter \n grec nom...       194
