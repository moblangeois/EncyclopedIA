# %%
import re
import json
import os
import unicodedata

def clean_filename(filename):
    filename = unicodedata.normalize('NFKD', filename).encode('ASCII', 'ignore').decode('ASCII')
    filename = re.sub(r'[^\w\-_\. ]', '_', filename)
    filename = filename.replace(' ', '_')
    filename = re.sub(r'_+', '_', filename)
    return filename[:200]

def parse_article(text):
    article = {}
    
    # Extraire la vedette
    vedette_match = re.match(r'^([A-ZÉÈ\s]+)', text)
    if vedette_match:
        article['vedette'] = vedette_match.group(1).strip()
    else:
        return None  # Si pas de vedette, ce n'est probablement pas un article valide
    
    # Extraire l'indication grammaticale et le désignant
    info_match = re.search(r',\s*([\w\.\s]+)?\s*\(([\w\s&]+)\)', text)
    if info_match:
        if info_match.group(1):
            article['indication_grammaticale'] = info_match.group(1).strip()
        article['designants'] = [d.strip() for d in info_match.group(2).split('&')]
    
    # Extraire la signature
    signature_match = re.search(r'\(([A-Z])\)$', text)
    if signature_match:
        article['signature'] = signature_match.group(1)
    
    # Extraire les renvois encyclopédiques
    renvois_match = re.search(r'Voyez\s+([\w\s,&]+)', text)
    if renvois_match:
        article['renvois'] = [r.strip() for r in re.split(r'[,&]', renvois_match.group(1))]
    
    # Extraire le contenu principal
    content_match = re.search(r'\)\s*(.*?)(?=\n\n[A-ZÉÈ\s]+[,\(]|\Z)', text, re.DOTALL)
    if content_match:
        article['contenu'] = content_match.group(1).strip()
    
    return article

def process_file(input_filepath, output_directory):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)
    
    article_count = 0
    
    with open(input_filepath, 'r', encoding='utf-8') as file:
        content = file.read()
    
    articles = re.split(r'\n\n(?=[A-ZÉÈ\s]+[,\(])', content)
    
    for article_text in articles:
        parsed_article = parse_article(article_text)
        if parsed_article:
            filename = clean_filename(parsed_article['vedette'].lower()) + '.json'
            filepath = os.path.join(output_directory, filename)
            with open(filepath, 'w', encoding='utf-8') as json_file:
                json.dump(parsed_article, json_file, ensure_ascii=False, indent=2)
            article_count += 1
            if article_count % 100 == 0:
                print(f"Processed {article_count} articles")
    
    print(f"Total articles processed: {article_count}")

if __name__ == "__main__":
    input_filepath = "data/cleanedMergedDiderot.txt"
    output_directory = "cleaned_articles"
    process_file(input_filepath, output_directory)
# Out:
# Processed 100 articles
# Processed 200 articles
# Processed 300 articles
# Processed 400 articles
# Processed 500 articles
# Processed 600 articles
# Processed 700 articles
# Processed 800 articles
# Processed 900 articles
# Processed 1000 articles
# Processed 1100 articles
# Processed 1200 articles
# Processed 1300 articles
# Processed 1400 articles
# Processed 1500 articles
# Processed 1600 articles
# Processed 1700 articles
# Processed 1800 articles
# Processed 1900 articles
# Processed 2000 articles
# Processed 2100 articles
# Processed 2200 articles
# Processed 2300 articles
# Processed 2400 articles
# Processed 2500 articles
# Processed 2600 articles
# Processed 2700 articles
# Processed 2800 articles
# Processed 2900 articles
# Processed 3000 articles
# Processed 3100 articles
# Processed 3200 articles
# Processed 3300 articles
# Processed 3400 articles
# Processed 3500 articles
# Processed 3600 articles
# Processed 3700 articles
# Processed 3800 articles
# Processed 3900 articles
# Processed 4000 articles
# Processed 4100 articles
# Processed 4200 articles
# Processed 4300 articles
# Processed 4400 articles
# Processed 4500 articles
# Processed 4600 articles
# Processed 4700 articles
# Processed 4800 articles
# Processed 4900 articles
# Processed 5000 articles
# Processed 5100 articles
# Processed 5200 articles
# Processed 5300 articles
# Processed 5400 articles
# Processed 5500 articles
# Processed 5600 articles
# Processed 5700 articles
# Processed 5800 articles
# Processed 5900 articles
# Processed 6000 articles
# Processed 6100 articles
# Processed 6200 articles
# Processed 6300 articles
# Processed 6400 articles
# Processed 6500 articles
# Processed 6600 articles
# Processed 6700 articles
# Processed 6800 articles
# Processed 6900 articles
# Processed 7000 articles
# Processed 7100 articles
# Processed 7200 articles
# Processed 7300 articles
# Processed 7400 articles
# Processed 7500 articles
# Processed 7600 articles
# Processed 7700 articles
# Processed 7800 articles
# Processed 7900 articles
# Processed 8000 articles
# Processed 8100 articles
# Processed 8200 articles
# Processed 8300 articles
# Processed 8400 articles
# Processed 8500 articles
# Processed 8600 articles
# Processed 8700 articles
# Processed 8800 articles
# Processed 8900 articles
# Processed 9000 articles
# Processed 9100 articles
# Processed 9200 articles
# Processed 9300 articles
# Processed 9400 articles
# Processed 9500 articles
# Processed 9600 articles
# Processed 9700 articles
# Processed 9800 articles
# Processed 9900 articles
# Processed 10000 articles
# Processed 10100 articles
# Processed 10200 articles
# Processed 10300 articles
# Processed 10400 articles
# Processed 10500 articles
# Processed 10600 articles
# Processed 10700 articles
# Processed 10800 articles
# Processed 10900 articles
# Processed 11000 articles
# Processed 11100 articles
# Processed 11200 articles
# Processed 11300 articles
# Processed 11400 articles
# Processed 11500 articles
# Processed 11600 articles
# Processed 11700 articles
# Processed 11800 articles
# Processed 11900 articles
# Processed 12000 articles
# Processed 12100 articles
# Processed 12200 articles
# Processed 12300 articles
# Processed 12400 articles
# Processed 12500 articles
# Processed 12600 articles
# Processed 12700 articles
# Processed 12800 articles
# Processed 12900 articles
# Processed 13000 articles
# Processed 13100 articles
# Processed 13200 articles
# Processed 13300 articles
# Processed 13400 articles
# Processed 13500 articles
# Processed 13600 articles
# Processed 13700 articles
# Processed 13800 articles
# Processed 13900 articles
# Processed 14000 articles
# Processed 14100 articles
# Processed 14200 articles
# Processed 14300 articles
# Processed 14400 articles
# Processed 14500 articles
# Processed 14600 articles
# Processed 14700 articles
# Processed 14800 articles
# Processed 14900 articles
# Processed 15000 articles
# Processed 15100 articles
# Processed 15200 articles
# Processed 15300 articles
# Processed 15400 articles
# Processed 15500 articles
# Processed 15600 articles
# Processed 15700 articles
# Processed 15800 articles
# Processed 15900 articles
# Processed 16000 articles
# Processed 16100 articles
# Processed 16200 articles
# Processed 16300 articles
# Processed 16400 articles
# Processed 16500 articles
# Processed 16600 articles
# Processed 16700 articles
# Processed 16800 articles
# Processed 16900 articles
# Processed 17000 articles
# Processed 17100 articles
# Processed 17200 articles
# Processed 17300 articles
# Processed 17400 articles
# Processed 17500 articles
# Processed 17600 articles
# Processed 17700 articles
# Processed 17800 articles
# Processed 17900 articles
# Processed 18000 articles
# Processed 18100 articles
# Processed 18200 articles
# Processed 18300 articles
# Processed 18400 articles
# Processed 18500 articles
# Processed 18600 articles
# Processed 18700 articles
# Processed 18800 articles
# Processed 18900 articles
# Processed 19000 articles
# Processed 19100 articles
# Processed 19200 articles
# Processed 19300 articles
# Processed 19400 articles
# Processed 19500 articles
# Processed 19600 articles
# Processed 19700 articles
# Processed 19800 articles
# Processed 19900 articles
# Processed 20000 articles
# Processed 20100 articles
# Processed 20200 articles
# Processed 20300 articles
# Processed 20400 articles
# Processed 20500 articles
# Processed 20600 articles
# Processed 20700 articles
# Processed 20800 articles
# Processed 20900 articles
# Processed 21000 articles
# Processed 21100 articles
# Processed 21200 articles
# Processed 21300 articles
# Processed 21400 articles
# Processed 21500 articles
# Processed 21600 articles
# Processed 21700 articles
# Processed 21800 articles
# Processed 21900 articles
# Processed 22000 articles
# Processed 22100 articles
# Processed 22200 articles
# Processed 22300 articles
# Processed 22400 articles
# Processed 22500 articles
# Processed 22600 articles
# Processed 22700 articles
# Processed 22800 articles
# Processed 22900 articles
# Processed 23000 articles
# Processed 23100 articles
# Processed 23200 articles
# Processed 23300 articles
# Processed 23400 articles
# Processed 23500 articles
# Processed 23600 articles
# Processed 23700 articles
# Processed 23800 articles
# Processed 23900 articles
# Processed 24000 articles
# Processed 24100 articles
# Processed 24200 articles
# Processed 24300 articles
# Processed 24400 articles
# Processed 24500 articles
# Processed 24600 articles
# Processed 24700 articles
# Processed 24800 articles
# Processed 24900 articles
# Processed 25000 articles
# Processed 25100 articles
# Processed 25200 articles
# Processed 25300 articles
# Processed 25400 articles
# Processed 25500 articles
# Processed 25600 articles
# Processed 25700 articles
# Processed 25800 articles
# Processed 25900 articles
# Processed 26000 articles
# Processed 26100 articles
# Processed 26200 articles
# Processed 26300 articles
# Processed 26400 articles
# Processed 26500 articles
# Processed 26600 articles
# Processed 26700 articles
# Processed 26800 articles
# Processed 26900 articles
# Processed 27000 articles
# Processed 27100 articles
# Processed 27200 articles
# Processed 27300 articles
# Processed 27400 articles
# Processed 27500 articles
# Processed 27600 articles
# Processed 27700 articles
# Processed 27800 articles
# Processed 27900 articles
# Processed 28000 articles
# Processed 28100 articles
# Processed 28200 articles
# Processed 28300 articles
# Processed 28400 articles
# Processed 28500 articles
# Processed 28600 articles
# Processed 28700 articles
# Processed 28800 articles
# Processed 28900 articles
# Processed 29000 articles
# Processed 29100 articles
# Processed 29200 articles
# Processed 29300 articles
# Processed 29400 articles
# Processed 29500 articles
# Processed 29600 articles
# Processed 29700 articles
# Processed 29800 articles
# Processed 29900 articles
# Processed 30000 articles
# Processed 30100 articles
# Processed 30200 articles
# Processed 30300 articles
# Processed 30400 articles
# Processed 30500 articles
# Processed 30600 articles
# Processed 30700 articles
# Processed 30800 articles
# Processed 30900 articles
# Processed 31000 articles
# Processed 31100 articles
# Processed 31200 articles
# Processed 31300 articles
# Processed 31400 articles
# Processed 31500 articles
# Processed 31600 articles
# Processed 31700 articles
# Processed 31800 articles
# Processed 31900 articles
# Processed 32000 articles
# Processed 32100 articles
# Processed 32200 articles
# Processed 32300 articles
# Processed 32400 articles
# Processed 32500 articles
# Processed 32600 articles
# Processed 32700 articles
# Processed 32800 articles
# Processed 32900 articles
# Processed 33000 articles
# Processed 33100 articles
# Processed 33200 articles
# Processed 33300 articles
# Processed 33400 articles
# Processed 33500 articles
# Processed 33600 articles
# Processed 33700 articles
# Processed 33800 articles
# Processed 33900 articles
# Processed 34000 articles
# Processed 34100 articles
# Processed 34200 articles
# Processed 34300 articles
# Processed 34400 articles
# Processed 34500 articles
# Processed 34600 articles
# Processed 34700 articles
# Processed 34800 articles
# Processed 34900 articles
# Processed 35000 articles
# Processed 35100 articles
# Processed 35200 articles
# Processed 35300 articles
# Processed 35400 articles
# Processed 35500 articles
# Processed 35600 articles
# Processed 35700 articles
# Processed 35800 articles
# Processed 35900 articles
# Processed 36000 articles
# Processed 36100 articles
# Processed 36200 articles
# Processed 36300 articles
# Processed 36400 articles
# Processed 36500 articles
# Processed 36600 articles
# Processed 36700 articles
# Processed 36800 articles
# Processed 36900 articles
# Processed 37000 articles
# Processed 37100 articles
# Processed 37200 articles
# Processed 37300 articles
# Processed 37400 articles
# Processed 37500 articles
# Processed 37600 articles
# Processed 37700 articles
# Processed 37800 articles
# Processed 37900 articles
# Total articles processed: 37924

# %%
import re
import json

def clean_filename(filename):
    import unicodedata
    filename = unicodedata.normalize('NFKD', filename).encode('ASCII', 'ignore').decode('ASCII')
    filename = re.sub(r'[^\w\-_\. ]', '_', filename)
    filename = filename.replace(' ', '_')
    filename = re.sub(r'_+', '_', filename)
    return filename[:200]

def parse_article(text):
    article = {}
    
    # Extraire la vedette
    vedette_match = re.match(r'^([A-ZÉÈ\s]+)', text)
    if vedette_match:
        article['vedette'] = vedette_match.group(1).strip()
    else:
        return None  # Si pas de vedette, ce n'est probablement pas un article valide
    
    # Extraire l'indication grammaticale et le désignant
    info_match = re.search(r',\s*([\w\.\s]+)?\s*\(([\w\s&]+)\)', text)
    if info_match:
        if info_match.group(1):
            article['indication_grammaticale'] = info_match.group(1).strip()
        article['designants'] = [d.strip() for d in info_match.group(2).split('&')]
    
    # Extraire la signature
    signature_match = re.search(r'\(([A-Z])\)$', text)
    if signature_match:
        article['signature'] = signature_match.group(1)
    
    # Extraire les renvois encyclopédiques
    renvois_match = re.search(r'Voyez\s+([\w\s,&]+)', text)
    if renvois_match:
        article['renvois'] = [r.strip() for r in re.split(r'[,&]', renvois_match.group(1))]
    
    # Extraire le contenu principal
    content_match = re.search(r'\)\s*(.*?)(?=\n\n[A-ZÉÈ\s]+[,\(]|\Z)', text, re.DOTALL)
    if content_match:
        article['contenu'] = content_match.group(1).strip()
    
    return article

# Test avec un article spécifique
article_text = """
ZÉTÉTIQUE, adj. (mathématiques) épithète que quelques auteurs donnent à une branche des mathématiques, qui s'occupe de la recherche ou de la solution des problèmes. Voyez Résolution & Problème.

Ce mot est formé du grec ζητειν, chercher.

Les anciens ont donné le nom de zététique à une méthode dont ils se servoient pour résoudre un problème. Ils commençoient par supposer que ce qu'on cherchoit étoit déjà trouvé ; puis ils examinoient ce qui résultoit de cette supposition ; & suivant le fil de ce raisonnement, ils parvenoient ou à découvrir ce qu'ils cherchoient, ou à en reconnoître l'impossibilité.

On donne aussi le nom de zététiques aux Pyrrhoniens. Voyez Pyrrhonien. (O)
"""

parsed_article = parse_article(article_text)
print(json.dumps(parsed_article, ensure_ascii=False, indent=2))

# %%
#Load EDdA_dataframe_withContent.tsv
import pandas as pd
df = pd.read_csv('data/EDdA_dataframe_withContent.tsv', sep='\t')

# %%
df
# Out:
#        volume  numero                                head           normClass  \
# 0           1       1                          Title Page        unclassified
# 1           1       2   A MONSEIGNEUR LE COMTE D'ARGENSON        unclassified
# 2           1       3  DISCOURS PRÉLIMINAIRE DES EDITEURS        unclassified
# 3           1       5                            A, a & a           Grammaire
# 4           1       6                                   A        unclassified
# ...       ...     ...                                 ...                 ...
# 74185      17    3204                           TRANSFUGE       Art militaire
# 74186      17    3205                               VÉNUS          Astronomie
# 74187      17    3206                       VERS falisque       Poésie latine
# 74188      17    3207           VIBRATION, ou OSCILLATION          Horlogerie
# 74189      17    3208               VINGTIEME, imposition  Economie politique
#
#                                                classEDdA  \
# 0                                           unclassified
# 1                                           unclassified
# 2                                           unclassified
# 3      ordre Encyclopéd. Entend. Science de l'homme, ...
# 4                                           unclassified
# ...                                                  ...
# 74185                                        Art. milit.
# 74186                                          Astronom.
# 74187                                     Poésie latine.
# 74188                                            Horlog.
# 74189                                         Econ. pol.
#
#                      author   id_enccre domaine_enccre  \
# 0                  unsigned         NaN            NaN
# 1      Diderot & d'Alembert         NaN            NaN
# 2                d'Alembert         NaN            NaN
# 3                Dumarsais5      v1-1-0      grammaire
# 4                Dumarsais5      v1-1-1      grammaire
# ...                     ...         ...            ...
# 74185        Saint-Lambert5  v17-2197-0            NaN
# 74186              unsigned  v17-2198-0     astronomie
# 74187              Jaucourt  v17-2199-0         poésie
# 74188              Romilly5  v17-2200-0     horlogerie
# 74189             Boulanger  v17-2201-0            NaN
#
#                            ensemble_domaine_enccre  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                        Grammaire
# 4                                        Grammaire
# ...                                            ...
# 74185                                          NaN
# 74186  Physique - [Sciences physico-mathématiques]
# 74187                      Belles-lettres - Poésie
# 74188                                      Métiers
# 74189                                          NaN
#
#                                                  content  \
# 0      ENCYCLOPÉDIE,\nDICTIONNAIRE RAISONNÉ\nDES SCIE...
# 1      A MONSEIGNEUR\nLE COMTE D'ARGENSON,\nMINISTRE\...
# 2      DISCOURS PRÉLIMINAIRE\nDES EDITEURS.\nL'Encycl...
# 3      A, a & a s.m. (ordre Encyclopéd.\nEntend. Scie...
# 4      A, mot, est 1. la troisieme personne du présen...
# ...                                                  ...
# 74185  TRANSFUGE, s. m. (Art. milit.) La plus grande\...
# 74186  VÉNUS, (Astronom.) satellites de Vénus. Depuis...
# 74187  VERS falisque, (Poésie latine.) vers latin de\...
# 74188  VIBRATION, ou OSCILLATION, s. f. (Horlog.) ter...
# 74189  VINGTIEME, imposition, s. m. (Econ. pol.)\ndan...
#
#                                      contentWithoutClass  \
# 0      encyclopédie \n dictionnaire raisonné \n scien...
# 1      a monseigneur \n comte argenson \n ministre \n...
# 2      discours préliminaire \n editeurs \n encyclopé...
# 3      a a a s.m ordre encyclopéd \n entend science h...
# 4      a mot 1 troisieme personne présent \n indicati...
# ...                                                  ...
# 74185  transfuge s. m.   grand \n partie europe étonn...
# 74186  vénus   satellite vénus depuis \n\n découverte...
# 74187  ver falisque   ver latin \n mesure précises a ...
# 74188  vibration oscillation s. f.   terme synonyme c...
# 74189  vingtieme imposition s. m. \n acception partic...
#
#                                           firstParagraph  nb_words
# 0      encyclopédie \n dictionnaire raisonné \n scien...       178
# 1      a monseigneur \n comte argenson \n ministre \n...       322
# 2      discours préliminaire \n editeurs \n encyclopé...     58294
# 3      a a a s.m ordre encyclopéd \n entend science h...      1092
# 4      a mot 1 troisieme personne présent \n indicati...       381
# ...                                                  ...       ...
# 74185  transfuge s. m.   grand \n partie europe étonn...      9576
# 74186  vénus   satellite vénus depuis \n\n découverte...      3754
# 74187  ver falisque   ver latin \n mesure précises a ...        97
# 74188  vibration oscillation s. f.   terme synonyme c...      4945
# 74189  vingtieme imposition s. m. \n acception partic...     56857
#
# [74190 rows x 13 columns]

# %%
from reportlab.lib.pagesizes import A4
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.enums import TA_JUSTIFY
import pandas as pd
import html
import re

def clean_text(text):
    if pd.isna(text):
        return "Contenu non disponible"
    # Convertir les caractères spéciaux HTML
    text = html.unescape(text)
    # Remplacer les sauts de ligne par <br/>
    text = text.replace('\n', '<br/>')
    # Échapper les caractères spéciaux XML
    text = text.replace('&', '&amp;').replace('<', '<').replace('>', '>')
    # Supprimer ou remplacer les caractères non-ASCII
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)
    return text

# Charger les données
df = pd.read_csv('data/EDdA_dataframe_withContent.tsv', sep='\t')

# Configurer les styles
styles = getSampleStyleSheet()
styles.add(ParagraphStyle(name='Justify', alignment=TA_JUSTIFY, fontName='Times-Roman'))

# Créer le document
doc = SimpleDocTemplate("Encyclopedie_Diderot_dAlembert.pdf", pagesize=A4,
                        rightMargin=72, leftMargin=72,
                        topMargin=72, bottomMargin=18)

Story = []

# Ajouter le titre
Story.append(Paragraph("Encyclopédie de Diderot et d'Alembert", styles['Title']))
Story.append(Spacer(1, 12))

# Parcourir les entrées et les ajouter au document
for index, row in df.iterrows():
    try:
        # Titre de l'entrée
        Story.append(Paragraph(clean_text(str(row['head'])), styles['Heading2']))
        Story.append(Spacer(1, 6))
        
        # Informations sur l'entrée
        info = f"Volume: {row['volume']}, Numéro: {row['numero']}, Auteur: {row['author']}"
        Story.append(Paragraph(clean_text(info), styles['Italic']))
        Story.append(Spacer(1, 6))
        
        # Contenu de l'entrée
        content = clean_text(str(row['content']))
        Story.append(Paragraph(content, styles['Justify']))
        Story.append(Spacer(1, 12))
        
        # Afficher la progression
        if (index + 1) % 100 == 0:
            print(f"Processed {index + 1} articles")
    except Exception as e:
        print(f"Error processing article {index + 1}: {str(e)}")
        continue

# Générer le PDF
try:
    doc.build(Story)
    print(f"Total articles processed: {len(df)}")
    print("PDF generated successfully")
except Exception as e:
    print(f"Error generating PDF: {str(e)}")
# Out:
# Processed 100 articles
# Processed 200 articles
# Processed 300 articles
# Processed 400 articles
# Processed 500 articles
# Processed 600 articles
# Processed 700 articles
# Processed 800 articles
# Processed 900 articles
# Processed 1000 articles
# Processed 1100 articles
# Processed 1200 articles
# Processed 1300 articles
# Processed 1400 articles
# Processed 1500 articles
# Processed 1600 articles
# Processed 1700 articles
# Processed 1800 articles
# Processed 1900 articles
# Processed 2000 articles
# Processed 2100 articles
# Processed 2200 articles
# Processed 2300 articles
# Processed 2400 articles
# Processed 2500 articles
# Processed 2600 articles
# Processed 2700 articles
# Processed 2800 articles
# Processed 2900 articles
# Processed 3000 articles
# Processed 3100 articles
# Processed 3200 articles
# Processed 3300 articles
# Processed 3400 articles
# Processed 3500 articles
# Processed 3600 articles
# Processed 3700 articles
# Processed 3800 articles
# Processed 3900 articles
# Processed 4000 articles
# Processed 4100 articles
# Processed 4200 articles
# Processed 4300 articles
# Processed 4400 articles
# Processed 4500 articles
# Processed 4600 articles
# Processed 4700 articles
# Processed 4800 articles
# Processed 4900 articles
# Processed 5000 articles
# Processed 5100 articles
# Processed 5200 articles
# Processed 5300 articles
# Processed 5400 articles
# Processed 5500 articles
# Processed 5600 articles
# Processed 5700 articles
# Processed 5800 articles
# Processed 5900 articles
# Processed 6000 articles
# Processed 6100 articles
# Processed 6200 articles
# Processed 6300 articles
# Processed 6400 articles
# Processed 6500 articles
# Processed 6600 articles
# Processed 6700 articles
# Processed 6800 articles
# Processed 6900 articles
# Processed 7000 articles
# Processed 7100 articles
# Processed 7200 articles
# Processed 7300 articles
# Processed 7400 articles
# Processed 7500 articles
# Processed 7600 articles
# Processed 7700 articles
# Processed 7800 articles
# Processed 7900 articles
# Processed 8000 articles
# Processed 8100 articles
# Processed 8200 articles
# Processed 8300 articles
# Processed 8400 articles
# Processed 8500 articles
# Processed 8600 articles
# Processed 8700 articles
# Processed 8800 articles
# Processed 8900 articles
# Processed 9000 articles
# Processed 9100 articles
# Processed 9200 articles
# Processed 9300 articles
# Processed 9400 articles
# Processed 9500 articles
# Processed 9600 articles
# Processed 9700 articles
# Processed 9800 articles
# Processed 9900 articles
# Processed 10000 articles
# Processed 10100 articles
# Processed 10200 articles
# Processed 10300 articles
# Processed 10400 articles
# Processed 10500 articles
# Processed 10600 articles
# Processed 10700 articles
# Processed 10800 articles
# Processed 10900 articles
# Processed 11000 articles
# Processed 11100 articles
# Processed 11200 articles
# Processed 11300 articles
# Processed 11400 articles
# Processed 11500 articles
# Processed 11600 articles
# Processed 11700 articles
# Processed 11800 articles
# Processed 11900 articles
# Processed 12000 articles
# Processed 12100 articles
# Processed 12200 articles
# Processed 12300 articles
# Processed 12400 articles
# Processed 12500 articles
# Processed 12600 articles
# Processed 12700 articles
# Processed 12800 articles
# Processed 12900 articles
# Processed 13000 articles
# Processed 13100 articles
# Processed 13200 articles
# Processed 13300 articles
# Processed 13400 articles
# Processed 13500 articles
# Processed 13600 articles
# Processed 13700 articles
# Processed 13800 articles
# Processed 13900 articles
# Processed 14000 articles
# Processed 14100 articles
# Processed 14200 articles
# Processed 14300 articles
# Processed 14400 articles
# Processed 14500 articles
# Processed 14600 articles
# Processed 14700 articles
# Processed 14800 articles
# Processed 14900 articles
# Processed 15000 articles
# Processed 15100 articles
# Processed 15200 articles
# Processed 15300 articles
# Processed 15400 articles
# Processed 15500 articles
# Processed 15600 articles
# Processed 15700 articles
# Processed 15800 articles
# Processed 15900 articles
# Processed 16000 articles
# Processed 16100 articles
# Processed 16200 articles
# Processed 16300 articles
# Processed 16400 articles
# Processed 16500 articles
# Processed 16600 articles
# Processed 16700 articles
# Processed 16800 articles
# Processed 16900 articles
# Processed 17000 articles
# Processed 17100 articles
# Processed 17200 articles
# Processed 17300 articles
# Processed 17400 articles
# Processed 17500 articles
# Processed 17600 articles
# Processed 17700 articles
# Processed 17800 articles
# Processed 17900 articles
# Processed 18000 articles
# Processed 18100 articles
# Processed 18200 articles
# Processed 18300 articles
# Processed 18400 articles
# Processed 18500 articles
# Processed 18600 articles
# Processed 18700 articles
# Processed 18800 articles
# Processed 18900 articles
# Processed 19000 articles
# Processed 19100 articles
# Processed 19200 articles
# Processed 19300 articles
# Processed 19400 articles
# Processed 19500 articles
# Processed 19600 articles
# Processed 19700 articles
# Processed 19800 articles
# Processed 19900 articles
# Processed 20000 articles
# Processed 20100 articles
# Processed 20200 articles
# Processed 20300 articles
# Processed 20400 articles
# Processed 20500 articles
# Processed 20600 articles
# Processed 20700 articles
# Processed 20800 articles
# Processed 20900 articles
# Processed 21000 articles
# Processed 21100 articles
# Processed 21200 articles
# Processed 21300 articles
# Processed 21400 articles
# Processed 21500 articles
# Processed 21600 articles
# Processed 21700 articles
# Processed 21800 articles
# Processed 21900 articles
# Processed 22000 articles
# Processed 22100 articles
# Processed 22200 articles
# Processed 22300 articles
# Processed 22400 articles
# Processed 22500 articles
# Processed 22600 articles
# Processed 22700 articles
# Processed 22800 articles
# Processed 22900 articles
# Processed 23000 articles
# Error processing article 23100:
# paragraph text "<para>Ellipse de M. Cassini, autrement nomm e cassino de, est une courbe que feu M. Jean Dominique<br/>Cassini avoit imagin e pour expliquer les mouvemens <br/>des planetes ; cette courbe a deux foyers F, f<br/>(fig. 24.), dont la propri t est telle que le produit<br/>F M X M f de deux lignes quelconques men es de<br/>ces foyers un point quelconque M de la courbe,<br/>est to jours gal une quantit constante ; au lieu<br/>que dans l'ellipse ordinaire ou d'Apollonius, c'est<br/>la somme de ces lignes, &amp; non leur produit, qui est<br/><br/><br/> gale une quantit constante. M. l'abb de Gua<br/>dans ses usages de l'analyse de Descartes, a d termin <br/>les principales propri t s de cette courbe. Il y examine <br/>les diff rentes figures qu'elle peut avoir, &amp;<br/>dont nous avons rapport quelques-unes l'article<br/>Conjugu , &amp; il conclud que cette courbe n'a pas<br/> t bien connue par ceux qui en ont parl avant lui,<br/>si on en excepte cependant l'illustre M. Gr gory.<br/>Voyez astron. physiq. &amp; g om tr. l ment. page 33'.<br/> dit. de Geneve, 1726, ou les trans. phil. Sept. 1704.<br/>Pour avoir une id e des propri t s de cette courbe,<br/>soit a son demi-axe, f la distance d'un des foyers<br/>au centre, x l'abscisse prise depuis le centre, y l'ordonn e,<br/>on aura, comme il est ais de le prouver<br/>par le calcul ,<br/>par la propri t de cette<br/>courbe, ou ,<br/>ou enfin ;<br/>donc, 1 . cette quation ne donnera<br/>jamais que deux valeurs r elles tout au plus pour y,<br/>l'une positive, l'autre n gative, &amp; gale la positive ; <br/>car les deux valeurs qu'on auroit en mettant le<br/>signe-devant seroient imaginaires,<br/>puisque y seroit la racine d'une quantit n gative.<br/>2 . En supposant m me le signe + devant<br/>cette derniere quantit , il est visible que la valeur<br/>de y ne sera r elle que quand ,<br/>c'est- dire quand .<br/>Donc si<br/>, l'ordonn e <br/>sera r elle, sinon elle sera imaginaire.<br/>Donc si a a=2 f f, l'ordonn e sera nulle au centre,<br/>&amp; la courbe aura la figure d'un 8 de chiffre ou<br/>lemniscate (Voyez Lemniscate); car on aura alors<br/>x x=ou>2 f f-a a, condition pour que l'ordonn e <br/>soit nulle ou r elle. Si 2 f f>a a, les ordonn es <br/>r elles ne commenceront qu'au point o ,<br/>&amp; elles finiront au point o x=a ;<br/>car (a a-f f)2 doit aussi tre>ou=(x x-f f)2.<br/>Ainsi dans ce cas la courbe sera compos e de deux<br/>courbes conjugu es &amp; isol es, distantes l'une de l'autre <br/>de la quantit ; &amp; si dans cette supposition <br/>on a de plus ou s=a, la<br/>courbe se r duira deux points conjugu s uniques.<br/>Si f>a, la courbe sera totalement imaginaire.<br/>Enfin si 2 f f<a a, la courbe sera continue, &amp; aura<br/>toutes ses ordonn es r elles, gales &amp; de signe contraire,<br/>depuis x=0 jusque' x=a.<br/>Cette courbe que M. Cassini avoit voulu introduire <br/>dans l'Astronomie, n'est plus qu'une courbe<br/>purement g om trique &amp; de simple curiosit , car on<br/>sait que les planetes d crivent des ellipses apolloniennes <br/>ou ordinaires. On demandera peut- tre par quelle<br/>raison M. Cassini avoit substitu cette ellipse celle<br/>de Kepler. Voici ma conjecture sur ce sujet. On sait<br/>que la pl part des planetes d crivent des ellipses peu<br/>excentriques. On sait aussi, &amp; on peut le conclure de<br/>l'article ellipse qui pr cede, que dans une ellipse peu<br/>excentrique les secteurs faits par les rayons vecteurs<br/> un foyer sont proportionnels tr s-peu-pr s aux<br/>angles correspondans faits l'autre foyer ; &amp; c'est<br/>sur cette propri t que Ward ou Sethus Wardus a tabli sa solution approch e du probl me qui consiste <br/>trouver l'anomalie vraie d'une planete, l'anomalie<br/>moyenne tant donn e. Voyez Ellipse &amp; Anomalie. Voyez aussi les instit. astronomiq. de M. le Monnier, page 506, &amp; suiv. Le rapport du secteur infiniment <br/>petit l'angle correspondant, est comme le<br/>rectangle des deux lignes men es au foyer, &amp; ...
# Processed 23200 articles
# Processed 23300 articles
# Processed 23400 articles
# Processed 23500 articles
# Processed 23600 articles
# Processed 23700 articles
# Processed 23800 articles
# Processed 23900 articles
# Processed 24000 articles
# Processed 24100 articles
# Processed 24200 articles
# Processed 24300 articles
# Processed 24400 articles
# Processed 24500 articles
# Processed 24600 articles
# Processed 24700 articles
# Processed 24800 articles
# Processed 24900 articles
# Processed 25000 articles
# Processed 25100 articles
# Processed 25200 articles
# Processed 25300 articles
# Processed 25400 articles
# Processed 25500 articles
# Processed 25600 articles
# Processed 25700 articles
# Processed 25800 articles
# Processed 25900 articles
# Processed 26000 articles
# Processed 26100 articles
# Processed 26200 articles
# Processed 26300 articles
# Processed 26400 articles
# Processed 26500 articles
# Processed 26600 articles
# Processed 26700 articles
# Processed 26800 articles
# Processed 26900 articles
# Processed 27000 articles
# Processed 27100 articles
# Processed 27200 articles
# Processed 27300 articles
# Processed 27400 articles
# Processed 27500 articles
# Processed 27600 articles
# Processed 27700 articles
# Processed 27800 articles
# Processed 27900 articles
# Processed 28000 articles
# Processed 28100 articles
# Processed 28200 articles
# Processed 28300 articles
# Processed 28400 articles
# Processed 28500 articles
# Processed 28600 articles
# Processed 28700 articles
# Processed 28800 articles
# Processed 28900 articles
# Processed 29000 articles
# Processed 29100 articles
# Processed 29200 articles
# Processed 29300 articles
# Processed 29400 articles
# Processed 29500 articles
# Processed 29600 articles
# Processed 29700 articles
# Processed 29800 articles
# Processed 29900 articles
# Processed 30000 articles
# Processed 30100 articles
# Processed 30200 articles
# Processed 30300 articles
# Processed 30400 articles
# Processed 30500 articles
# Processed 30600 articles
# Processed 30700 articles
# Processed 30800 articles
# Processed 30900 articles
# Processed 31000 articles
# Processed 31100 articles
# Processed 31200 articles
# Processed 31300 articles
# Processed 31400 articles
# Processed 31500 articles
# Processed 31600 articles
# Processed 31700 articles
# Processed 31800 articles
# Processed 31900 articles
# Processed 32000 articles
# Processed 32100 articles
# Processed 32200 articles
# Processed 32300 articles
# Processed 32400 articles
# Processed 32500 articles
# Processed 32600 articles
# Processed 32700 articles
# Processed 32800 articles
# Processed 32900 articles
# Processed 33000 articles
# Processed 33100 articles
# Processed 33200 articles
# Processed 33300 articles
# Processed 33400 articles
# Processed 33500 articles
# Processed 33600 articles
# Processed 33700 articles
# Processed 33800 articles
# Processed 33900 articles
# Processed 34000 articles
# Processed 34100 articles
# Processed 34200 articles
# Processed 34300 articles
# Processed 34400 articles
# Processed 34500 articles
# Processed 34600 articles
# Processed 34700 articles
# Processed 34800 articles
# Processed 34900 articles
# Processed 35000 articles
# Processed 35100 articles
# Processed 35200 articles
# Processed 35300 articles
# Processed 35400 articles
# Processed 35500 articles
# Processed 35600 articles
# Processed 35700 articles
# Processed 35800 articles
# Processed 35900 articles
# Processed 36000 articles
# Processed 36100 articles
# Processed 36200 articles
# Processed 36300 articles
# Processed 36400 articles
# Processed 36500 articles
# Processed 36600 articles
# Processed 36700 articles
# Processed 36800 articles
# Processed 36900 articles
# Processed 37000 articles
# Processed 37100 articles
# Processed 37200 articles
# Processed 37300 articles
# Processed 37400 articles
# Processed 37500 articles
# Processed 37600 articles
# Processed 37700 articles
# Processed 37800 articles
# Processed 37900 articles
# Processed 38000 articles
# Processed 38100 articles
# Processed 38200 articles
# Processed 38300 articles
# Processed 38400 articles
# Processed 38500 articles
# Processed 38600 articles
# Processed 38700 articles
# Processed 38800 articles
# Processed 38900 articles
# Processed 39000 articles
# Processed 39100 articles
# Processed 39200 articles
# Processed 39300 articles
# Processed 39400 articles
# Processed 39500 articles
# Processed 39600 articles
# Processed 39700 articles
# Processed 39800 articles
# Processed 39900 articles
# Processed 40000 articles
# Processed 40100 articles
# Processed 40200 articles
# Processed 40300 articles
# Processed 40400 articles
# Processed 40500 articles
# Processed 40600 articles
# Processed 40700 articles
# Processed 40800 articles
# Processed 40900 articles
# Processed 41000 articles
# Processed 41100 articles
# Processed 41200 articles
# Processed 41300 articles
# Processed 41400 articles
# Processed 41500 articles
# Processed 41600 articles
# Processed 41700 articles
# Processed 41800 articles
# Processed 41900 articles
# Processed 42000 articles
# Processed 42100 articles
# Processed 42200 articles
# Processed 42300 articles
# Processed 42400 articles
# Processed 42500 articles
# Processed 42600 articles
# Processed 42700 articles
# Processed 42800 articles
# Processed 42900 articles
# Processed 43000 articles
# Processed 43100 articles
# Processed 43200 articles
# Processed 43300 articles
# Processed 43400 articles
# Processed 43500 articles
# Processed 43600 articles
# Processed 43700 articles
# Processed 43800 articles
# Processed 43900 articles
# Processed 44000 articles
# Processed 44100 articles
# Processed 44200 articles
# Processed 44300 articles
# Processed 44400 articles
# Processed 44500 articles
# Processed 44600 articles
# Processed 44700 articles
# Processed 44800 articles
# Processed 44900 articles
# Processed 45000 articles
# Processed 45100 articles
# Processed 45200 articles
# Processed 45300 articles
# Processed 45400 articles
# Processed 45500 articles
# Processed 45600 articles
# Processed 45700 articles
# Processed 45800 articles
# Processed 45900 articles
# Processed 46000 articles
# Processed 46100 articles
# Processed 46200 articles
# Processed 46300 articles
# Processed 46400 articles
# Processed 46500 articles
# Processed 46600 articles
# Processed 46700 articles
# Processed 46800 articles
# Processed 46900 articles
# Processed 47000 articles
# Processed 47100 articles
# Processed 47200 articles
# Processed 47300 articles
# Processed 47400 articles
# Processed 47500 articles
# Processed 47600 articles
# Processed 47700 articles
# Processed 47800 articles
# Processed 47900 articles
# Processed 48000 articles
# Processed 48100 articles
# Processed 48200 articles
# Processed 48300 articles
# Processed 48400 articles
# Processed 48500 articles
# Processed 48600 articles
# Processed 48700 articles
# Processed 48800 articles
# Processed 48900 articles
# Processed 49000 articles
# Processed 49100 articles
# Processed 49200 articles
# Processed 49300 articles
# Processed 49400 articles
# Processed 49500 articles
# Processed 49600 articles
# Processed 49700 articles
# Processed 49800 articles
# Processed 49900 articles
# Processed 50000 articles
# Processed 50100 articles
# Processed 50200 articles
# Processed 50300 articles
# Processed 50400 articles
# Processed 50500 articles
# Processed 50600 articles
# Processed 50700 articles
# Processed 50800 articles
# Processed 50900 articles
# Processed 51000 articles
# Processed 51100 articles
# Processed 51200 articles
# Processed 51300 articles
# Processed 51400 articles
# Processed 51500 articles
# Processed 51600 articles
# Processed 51700 articles
# Processed 51800 articles
# Processed 51900 articles
# Processed 52000 articles
# Processed 52100 articles
# Processed 52200 articles
# Processed 52300 articles
# Processed 52400 articles
# Processed 52500 articles
# Processed 52600 articles
# Processed 52700 articles
# Processed 52800 articles
# Processed 52900 articles
# Processed 53000 articles
# Processed 53100 articles
# Processed 53200 articles
# Processed 53300 articles
# Processed 53400 articles
# Processed 53500 articles
# Processed 53600 articles
# Processed 53700 articles
# Processed 53800 articles
# Processed 53900 articles
# Processed 54000 articles
# Processed 54100 articles
# Processed 54200 articles
# Processed 54300 articles
# Processed 54400 articles
# Processed 54500 articles
# Processed 54600 articles
# Processed 54700 articles
# Processed 54800 articles
# Processed 54900 articles
# Processed 55000 articles
# Processed 55100 articles
# Processed 55200 articles
# Processed 55300 articles
# Processed 55400 articles
# Processed 55500 articles
# Processed 55600 articles
# Processed 55700 articles
# Processed 55800 articles
# Processed 55900 articles
# Processed 56000 articles
# Processed 56100 articles
# Processed 56200 articles
# Processed 56300 articles
# Processed 56400 articles
# Processed 56500 articles
# Processed 56600 articles
# Processed 56700 articles
# Processed 56800 articles
# Processed 56900 articles
# Processed 57000 articles
# Processed 57100 articles
# Processed 57200 articles
# Processed 57300 articles
# Processed 57400 articles
# Processed 57500 articles
# Processed 57600 articles
# Processed 57700 articles
# Processed 57800 articles
# Processed 57900 articles
# Processed 58000 articles
# Processed 58100 articles
# Processed 58200 articles
# Processed 58300 articles
# Processed 58400 articles
# Processed 58500 articles
# Processed 58600 articles
# Processed 58700 articles
# Processed 58800 articles
# Processed 58900 articles
# Processed 59000 articles
# Processed 59100 articles
# Processed 59200 articles
# Processed 59300 articles
# Processed 59400 articles
# Processed 59500 articles
# Processed 59600 articles
# Processed 59700 articles
# Processed 59800 articles
# Processed 59900 articles
# Processed 60000 articles
# Processed 60100 articles
# Processed 60200 articles
# Processed 60300 articles
# Processed 60400 articles
# Processed 60500 articles
# Processed 60600 articles
# Processed 60700 articles
# Processed 60800 articles
# Processed 60900 articles
# Processed 61000 articles
# Processed 61100 articles
# Processed 61200 articles
# Processed 61300 articles
# Processed 61400 articles
# Processed 61500 articles
# Processed 61600 articles
# Processed 61700 articles
# Processed 61800 articles
# Processed 61900 articles
# Processed 62000 articles
# Processed 62100 articles
# Processed 62200 articles
# Processed 62300 articles
# Processed 62400 articles
# Processed 62500 articles
# Processed 62600 articles
# Processed 62700 articles
# Processed 62800 articles
# Processed 62900 articles
# Processed 63000 articles
# Processed 63100 articles
# Processed 63200 articles
# Processed 63300 articles
# Processed 63400 articles
# Processed 63500 articles
# Processed 63600 articles
# Processed 63700 articles
# Processed 63800 articles
# Processed 63900 articles
# Processed 64000 articles
# Processed 64100 articles
# Processed 64200 articles
# Processed 64300 articles
# Processed 64400 articles
# Processed 64500 articles
# Processed 64600 articles
# Processed 64700 articles
# Processed 64800 articles
# Processed 64900 articles
# Processed 65000 articles
# Processed 65100 articles
# Processed 65200 articles
# Processed 65300 articles
# Processed 65400 articles
# Processed 65500 articles
# Processed 65600 articles
# Processed 65700 articles
# Processed 65800 articles
# Processed 65900 articles
# Processed 66000 articles
# Processed 66100 articles
# Processed 66200 articles
# Processed 66300 articles
# Processed 66400 articles
# Processed 66500 articles
# Processed 66600 articles
# Processed 66700 articles
# Processed 66800 articles
# Processed 66900 articles
# Processed 67000 articles
# Processed 67100 articles
# Processed 67200 articles
# Processed 67300 articles
# Processed 67400 articles
# Processed 67500 articles
# Processed 67600 articles
# Processed 67700 articles
# Processed 67800 articles
# Processed 67900 articles
# Processed 68000 articles
# Processed 68100 articles
# Processed 68200 articles
# Processed 68300 articles
# Processed 68400 articles
# Processed 68500 articles
# Processed 68600 articles
# Processed 68700 articles
# Processed 68800 articles
# Processed 68900 articles
# Processed 69000 articles
# Processed 69100 articles
# Processed 69200 articles
# Processed 69300 articles
# Processed 69400 articles
# Processed 69500 articles
# Processed 69600 articles
# Processed 69700 articles
# Processed 69800 articles
# Processed 69900 articles
# Processed 70000 articles
# Processed 70100 articles
# Processed 70200 articles
# Processed 70300 articles
# Processed 70400 articles
# Processed 70500 articles
# Processed 70600 articles
# Processed 70700 articles
# Processed 70800 articles
# Processed 70900 articles
# Processed 71000 articles
# Processed 71100 articles
# Processed 71200 articles
# Processed 71300 articles
# Processed 71400 articles
# Processed 71500 articles
# Processed 71600 articles
# Processed 71700 articles
# Processed 71800 articles
# Processed 71900 articles
# Processed 72000 articles
# Processed 72100 articles
# Processed 72200 articles
# Processed 72300 articles
# Processed 72400 articles
# Processed 72500 articles
# Processed 72600 articles
# Processed 72700 articles
# Processed 72800 articles
# Processed 72900 articles
# Processed 73000 articles
# Processed 73100 articles
# Processed 73200 articles
# Processed 73300 articles
# Processed 73400 articles
# Processed 73500 articles
# Processed 73600 articles
# Processed 73700 articles
# Processed 73800 articles
# Processed 73900 articles
# Processed 74000 articles
# Processed 74100 articles
# Total articles processed: 74190
# PDF generated successfully

# %%
from PyPDF2 import PdfReader, PdfWriter

# Open the PDF file
pdf_path = "Encyclopedie_Diderot_dAlembert.pdf"

# Create a PDF reader object
pdf_reader = PdfReader(pdf_path)

# Get the number of pages in the PDF
num_pages = len(pdf_reader.pages)

# Get the first 15 pages (or all pages if less than 15)
num_pages_subset = min(15, num_pages)
pdf_writer = PdfWriter()
for page_num in range(num_pages_subset):
    pdf_writer.add_page(pdf_reader.pages[page_num])

# Create a new PDF file
output_pdf = "Encyclopedie_Diderot_dAlembert_subset.pdf"

# Write the subset to a new file
with open(output_pdf, 'wb') as output_file:
    pdf_writer.write(output_file)

print(f"Created subset PDF with {num_pages_subset} pages: {output_pdf}")
# Out:
# Created subset PDF with 15 pages: Encyclopedie_Diderot_dAlembert_subset.pdf
